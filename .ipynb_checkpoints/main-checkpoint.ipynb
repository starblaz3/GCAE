# %%
from keras.datasets import imdb
import pandas as pd
import numpy as np
from keras.layers import LSTM, Activation, Dropout, Dense, Input
from keras.layers.embeddings import Embedding
from keras.models import Model
import string
import re
from keras.preprocessing.text import Tokenizer
from sklearn.preprocessing import LabelBinarizer
from keras.preprocessing.sequence import pad_sequences
from tensorflow import keras
from sklearn.model_selection import train_test_split
import tensorflow as tf
from keras import Sequential
from keras.layers import Dense, Conv1D, Flatten,MaxPooling1D

# %%
data = pd.read_csv('../IMDB Dataset.csv')
data['review'] = data['review'].str.lower()

# %%
data
# Out:
#                                                   review sentiment
# 0      one of the other reviewers has mentioned that ...  positive
# 1      a wonderful little production. <br /><br />the...  positive
# 2      i thought this was a wonderful way to spend ti...  positive
# 3      basically there's a family where a little boy ...  negative
# 4      petter mattei's "love in the time of money" is...  positive
# ...                                                  ...       ...
# 49995  i thought this movie did a down right good job...  positive
# 49996  bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  i am a catholic taught in parochial elementary...  negative
# 49998  i'm going to have to disagree with the previou...  negative
# 49999  no one expects the star trek movies to be high...  negative
#
# [50000 rows x 2 columns]

# %%
stopwords = [ "a", "about", "above", "after", "again", "against", "all", "am", "an", "and", "any", "are", "as", "at", "be", "because", 
             "been", "before", "being", "below", "between", "both", "but", "by", "could", "did", "do", "does", "doing", "down", "during",
             "each", "few", "for", "from", "further", "had", "has", "have", "having", "he", "he'd", "he'll", "he's", "her", "here", 
             "here's", "hers", "herself", "him", "himself", "his", "how", "how's", "i", "i'd", "i'll", "i'm", "i've", "if", "in", "into",
             "is", "it", "it's", "its", "itself", "let's", "me", "more", "most", "my", "myself", "nor", "of", "on", "once", "only", "or",
             "other", "ought", "our", "ours", "ourselves", "out", "over", "own", "same", "she", "she'd", "she'll", "she's", "should", 
             "so", "some", "such", "than", "that", "that's", "the", "their", "theirs", "them", "themselves", "then", "there", "there's",
             "these", "they", "they'd", "they'll", "they're", "they've", "this", "those", "through", "to", "too", "under", "until", "up",
             "very", "was", "we", "we'd", "we'll", "we're", "we've", "were", "what", "what's", "when", "when's", "where", "where's",
             "which", "while", "who", "who's", "whom", "why", "why's", "with", "would", "you", "you'd", "you'll", "you're", "you've",
             "your", "yours", "yourself", "yourselves" ]

# %%
def remove_stopwords(data):
    data['review without stopwords'] = data['review'].apply(lambda x : ' '.join([word for word in x.split() if word not in (stopwords)]))
    return data

def remove_tags(string):
    result = re.sub('<.*?>','',string)
    return result
    
data_without_stopwords = remove_stopwords(data)
data_without_stopwords['clean_review']= data_without_stopwords['review without stopwords'].apply(lambda cw : remove_tags(cw))
data_without_stopwords['clean_review'] = data_without_stopwords['clean_review'].str.replace('[{}]'.format(string.punctuation), ' ')
# Out:
# <ipython-input-5-c2c05871866e>:11: FutureWarning: The default value of regex will change from True to False in a future version.
#   data_without_stopwords['clean_review'] = data_without_stopwords['clean_review'].str.replace('[{}]'.format(string.punctuation), ' ')

# %%
data_without_stopwords
# Out:
#                                                   review sentiment  \
# 0      one of the other reviewers has mentioned that ...  positive
# 1      a wonderful little production. <br /><br />the...  positive
# 2      i thought this was a wonderful way to spend ti...  positive
# 3      basically there's a family where a little boy ...  negative
# 4      petter mattei's "love in the time of money" is...  positive
# ...                                                  ...       ...
# 49995  i thought this movie did a down right good job...  positive
# 49996  bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  i am a catholic taught in parochial elementary...  negative
# 49998  i'm going to have to disagree with the previou...  negative
# 49999  no one expects the star trek movies to be high...  negative
#
#                                 review without stopwords  \
# 0      one reviewers mentioned watching just 1 oz epi...
# 1      wonderful little production. <br /><br />the f...
# 2      thought wonderful way spend time hot summer we...
# 3      basically family little boy (jake) thinks zomb...
# 4      petter mattei's "love time money" visually stu...
# ...                                                  ...
# 49995  thought movie right good job. wasn't creative ...
# 49996  bad plot, bad dialogue, bad acting, idiotic di...
# 49997  catholic taught parochial elementary schools n...
# 49998  going disagree previous comment side maltin on...
# 49999  no one expects star trek movies high art, fans...
#
#                                             clean_review
# 0      one reviewers mentioned watching just 1 oz epi...
# 1      wonderful little production  the filming techn...
# 2      thought wonderful way spend time hot summer we...
# 3      basically family little boy  jake  thinks zomb...
# 4      petter mattei s  love time money  visually stu...
# ...                                                  ...
# 49995  thought movie right good job  wasn t creative ...
# 49996  bad plot  bad dialogue  bad acting  idiotic di...
# 49997  catholic taught parochial elementary schools n...
# 49998  going disagree previous comment side maltin on...
# 49999  no one expects star trek movies high art  fans...
#
# [50000 rows x 4 columns]

# %%
reviews_list = []
sentiment = []
for i in range(len(data_without_stopwords)):
    reviews_list.append(data_without_stopwords.iloc[i,3])
    sentiment.append(data_without_stopwords.loc[i,'sentiment'])

# %%
y = np.array(list(map(lambda x: 1 if x=="positive" else 0, sentiment)))

X_train, X_test,Y_train, Y_test = train_test_split(reviews_list, y, test_size=0.2, random_state = 45)

# %%
words_to_index
# Out:
# {'movie': 1,
#  'film': 2,
#  's': 3,
#  't': 4,
#  'not': 5,
#  'one': 6,
#  'like': 7,
#  'just': 8,
#  'good': 9,
#  'it': 10,
#  'can': 11,
#  'the': 12,
#  'no': 13,
#  'time': 14,
#  'even': 15,
#  'really': 16,
#  'story': 17,
#  'see': 18,
#  'well': 19,
#  'much': 20,
#  'bad': 21,
#  'get': 22,
#  'great': 23,
#  'people': 24,
#  'will': 25,
#  'also': 26,
#  'first': 27,
#  'don': 28,
#  'made': 29,
#  'make': 30,
#  'way': 31,
#  'i': 32,
#  'movies': 33,
#  'characters': 34,
#  'think': 35,
#  'character': 36,
#  'watch': 37,
#  'films': 38,
#  'two': 39,
#  'many': 40,
#  'seen': 41,
#  'love': 42,
#  'plot': 43,
#  'acting': 44,
#  'never': 45,
#  'life': 46,
#  'best': 47,
#  'show': 48,
#  'know': 49,
#  'this': 50,
#  'little': 51,
#  'ever': 52,
#  'off': 53,
#  'man': 54,
#  'better': 55,
#  'end': 56,
#  'still': 57,
#  'scene': 58,
#  'say': 59,
#  'and': 60,
#  'scenes': 61,
#  'something': 62,
#  'go': 63,
#  'back': 64,
#  'real': 65,
#  'now': 66,
#  'thing': 67,
#  'watching': 68,
#  'actors': 69,
#  'director': 70,
#  'years': 71,
#  'funny': 72,
#  'didn': 73,
#  'though': 74,
#  'doesn': 75,
#  'old': 76,
#  'another': 77,
#  'work': 78,
#  '10': 79,
#  'actually': 80,
#  'nothing': 81,
#  'makes': 82,
#  'look': 83,
#  'all': 84,
#  'find': 85,
#  'going': 86,
#  'new': 87,
#  'lot': 88,
#  'every': 89,
#  'part': 90,
#  'cast': 91,
#  'world': 92,
#  'that': 93,
#  'us': 94,
#  'things': 95,
#  'pretty': 96,
#  'horror': 97,
#  'quite': 98,
#  'want': 99,
#  'around': 100,
#  'seems': 101,
#  'however': 102,
#  'take': 103,
#  'young': 104,
#  'big': 105,
#  'fact': 106,
#  'got': 107,
#  'thought': 108,
#  'in': 109,
#  'long': 110,
#  'enough': 111,
#  'give': 112,
#  'may': 113,
#  'series': 114,
#  'comedy': 115,
#  'right': 116,
#  'must': 117,
#  'action': 118,
#  'music': 119,
#  'guy': 120,
#  'almost': 121,
#  'without': 122,
#  'always': 123,
#  'role': 124,
#  'times': 125,
#  'saw': 126,
#  'original': 127,
#  'come': 128,
#  'point': 129,
#  'isn': 130,
#  'gets': 131,
#  'interesting': 132,
#  'a': 133,
#  'is': 134,
#  'whole': 135,
#  'done': 136,
#  'least': 137,
#  'script': 138,
#  'far': 139,
#  'me': 140,
#  'bit': 141,
#  '2': 142,
#  'anything': 143,
#  'feel': 144,
#  'minutes': 145,
#  'might': 146,
#  'family': 147,
#  'there': 148,
#  'making': 149,
#  'tv': 150,
#  'since': 151,
#  'last': 152,
#  'probably': 153,
#  'but': 154,
#  'kind': 155,
#  'away': 156,
#  'performance': 157,
#  'yet': 158,
#  'girl': 159,
#  'fun': 160,
#  'worst': 161,
#  'anyone': 162,
#  'woman': 163,
#  'sure': 164,
#  'hard': 165,
#  'rather': 166,
#  'day': 167,
#  'out': 168,
#  'found': 169,
#  'played': 170,
#  'on': 171,
#  'you': 172,
#  'them': 173,
#  'screen': 174,
#  'although': 175,
#  'looking': 176,
#  'especially': 177,
#  'believe': 178,
#  'him': 179,
#  'up': 180,
#  'so': 181,
#  'dvd': 182,
#  'trying': 183,
#  'everything': 184,
#  'course': 185,
#  'here': 186,
#  'set': 187,
#  'comes': 188,
#  'put': 189,
#  'ending': 190,
#  'maybe': 191,
#  'goes': 192,
#  'shows': 193,
#  'different': 194,
#  'worth': 195,
#  'place': 196,
#  'actor': 197,
#  'three': 198,
#  'book': 199,
#  'sense': 200,
#  'looks': 201,
#  'effects': 202,
#  'year': 203,
#  'someone': 204,
#  'money': 205,
#  'main': 206,
#  'american': 207,
#  'play': 208,
#  'true': 209,
#  'everyone': 210,
#  'watched': 211,
#  'reason': 212,
#  'job': 213,
#  'war': 214,
#  'wasn': 215,
#  'together': 216,
#  'again': 217,
#  'high': 218,
#  'plays': 219,
#  'said': 220,
#  'instead': 221,
#  'audience': 222,
#  'half': 223,
#  'later': 224,
#  'special': 225,
#  '1': 226,
#  'takes': 227,
#  'night': 228,
#  'seeing': 229,
#  'beautiful': 230,
#  'john': 231,
#  'black': 232,
#  'seem': 233,
#  'excellent': 234,
#  'left': 235,
#  'idea': 236,
#  'shot': 237,
#  'wife': 238,
#  'version': 239,
#  'house': 240,
#  'else': 241,
#  'star': 242,
#  'mind': 243,
#  'fan': 244,
#  'father': 245,
#  'nice': 246,
#  'used': 247,
#  'death': 248,
#  'short': 249,
#  'simply': 250,
#  'completely': 251,
#  'poor': 252,
#  'budget': 253,
#  'men': 254,
#  '3': 255,
#  'read': 256,
#  'second': 257,
#  'top': 258,
#  'less': 259,
#  'along': 260,
#  'hollywood': 261,
#  'let': 262,
#  'home': 263,
#  'kids': 264,
#  'line': 265,
#  'help': 266,
#  'either': 267,
#  'friends': 268,
#  'wrong': 269,
#  'dead': 270,
#  'enjoy': 271,
#  'boring': 272,
#  'school': 273,
#  'women': 274,
#  'camera': 275,
#  'need': 276,
#  'classic': 277,
#  'given': 278,
#  'try': 279,
#  'to': 280,
#  'use': 281,
#  'stupid': 282,
#  'production': 283,
#  'full': 284,
#  'low': 285,
#  'rest': 286,
#  'performances': 287,
#  'her': 288,
#  'as': 289,
#  'truly': 290,
#  'next': 291,
#  'couple': 292,
#  'start': 293,
#  'awful': 294,
#  'video': 295,
#  'too': 296,
#  'came': 297,
#  'sex': 298,
#  'recommend': 299,
#  'tell': 300,
#  'terrible': 301,
#  'getting': 302,
#  'name': 303,
#  'remember': 304,
#  'understand': 305,
#  'won': 306,
#  'perhaps': 307,
#  'mean': 308,
#  'moments': 309,
#  'mother': 310,
#  'person': 311,
#  'episode': 312,
#  'style': 313,
#  'small': 314,
#  'if': 315,
#  'playing': 316,
#  'keep': 317,
#  'definitely': 318,
#  'perfect': 319,
#  'others': 320,
#  'human': 321,
#  'wonderful': 322,
#  'face': 323,
#  'often': 324,
#  'early': 325,
#  'written': 326,
#  'head': 327,
#  'boy': 328,
#  'lines': 329,
#  'stars': 330,
#  'dialogue': 331,
#  'children': 332,
#  'couldn': 333,
#  'piece': 334,
#  'yes': 335,
#  'title': 336,
#  'finally': 337,
#  'laugh': 338,
#  'gives': 339,
#  'went': 340,
#  'case': 341,
#  'certainly': 342,
#  'absolutely': 343,
#  'live': 344,
#  'sort': 345,
#  'lost': 346,
#  'oh': 347,
#  'friend': 348,
#  'loved': 349,
#  'cinema': 350,
#  'entertaining': 351,
#  'worse': 352,
#  'become': 353,
#  'called': 354,
#  'hope': 355,
#  'picture': 356,
#  'for': 357,
#  'guys': 358,
#  'mr': 359,
#  'overall': 360,
#  'several': 361,
#  'felt': 362,
#  'liked': 363,
#  'drama': 364,
#  'what': 365,
#  'supposed': 366,
#  'based': 367,
#  'entire': 368,
#  'white': 369,
#  'problem': 370,
#  'beginning': 371,
#  'with': 372,
#  '4': 373,
#  'fans': 374,
#  'waste': 375,
#  'humor': 376,
#  'totally': 377,
#  'care': 378,
#  'evil': 379,
#  'sound': 380,
#  'dark': 381,
#  'despite': 382,
#  'final': 383,
#  'seemed': 384,
#  '5': 385,
#  'direction': 386,
#  'wanted': 387,
#  'example': 388,
#  'game': 389,
#  'already': 390,
#  'son': 391,
#  'lead': 392,
#  'who': 393,
#  'lives': 394,
#  'of': 395,
#  'becomes': 396,
#  'guess': 397,
#  'throughout': 398,
#  'michael': 399,
#  'turn': 400,
#  'killer': 401,
#  'quality': 402,
#  'unfortunately': 403,
#  'able': 404,
#  'side': 405,
#  'history': 406,
#  'over': 407,
#  'b': 408,
#  'fine': 409,
#  'days': 410,
#  'run': 411,
#  'writing': 412,
#  'viewer': 413,
#  'horrible': 414,
#  'god': 415,
#  'flick': 416,
#  'be': 417,
#  'child': 418,
#  'today': 419,
#  'wants': 420,
#  'heart': 421,
#  'close': 422,
#  'act': 423,
#  'town': 424,
#  '\x96': 425,
#  'or': 426,
#  'do': 427,
#  'kill': 428,
#  'past': 429,
#  'stuff': 430,
#  'amazing': 431,
#  'matter': 432,
#  'art': 433,
#  'works': 434,
#  'car': 435,
#  'kid': 436,
#  'favorite': 437,
#  'gave': 438,
#  'genre': 439,
#  'enjoyed': 440,
#  'etc': 441,
#  'hand': 442,
#  'eyes': 443,
#  'tries': 444,
#  'expect': 445,
#  'hour': 446,
#  'girls': 447,
#  'brilliant': 448,
#  'turns': 449,
#  'late': 450,
#  'soon': 451,
#  'behind': 452,
#  'parts': 453,
#  'sometimes': 454,
#  'directed': 455,
#  'killed': 456,
#  'highly': 457,
#  'actress': 458,
#  'obviously': 459,
#  'daughter': 460,
#  'thinking': 461,
#  'was': 462,
#  'says': 463,
#  'city': 464,
#  'type': 465,
#  'voice': 466,
#  'which': 467,
#  'then': 468,
#  'self': 469,
#  'group': 470,
#  'feeling': 471,
#  'decent': 472,
#  'starts': 473,
#  'experience': 474,
#  'writer': 475,
#  'heard': 476,
#  'took': 477,
#  'stop': 478,
#  'anyway': 479,
#  'known': 480,
#  'blood': 481,
#  'except': 482,
#  'slow': 483,
#  'happens': 484,
#  'moment': 485,
#  'fight': 486,
#  'coming': 487,
#  'involved': 488,
#  'police': 489,
#  'leave': 490,
#  'chance': 491,
#  'lack': 492,
#  'hell': 493,
#  'score': 494,
#  'cannot': 495,
#  'strong': 496,
#  'stories': 497,
#  'told': 498,
#  'crap': 499,
#  'extremely': 500,
#  'roles': 501,
#  'please': 502,
#  'wouldn': 503,
#  'wonder': 504,
#  'hilarious': 505,
#  'more': 506,
#  'hit': 507,
#  'including': 508,
#  'violence': 509,
#  'song': 510,
#  'happen': 511,
#  'hero': 512,
#  'obvious': 513,
#  'particularly': 514,
#  'cool': 515,
#  'living': 516,
#  'serious': 517,
#  'brother': 518,
#  'cut': 519,
#  'simple': 520,
#  'ok': 521,
#  'looked': 522,
#  'age': 523,
#  'complete': 524,
#  'ago': 525,
#  'reality': 526,
#  'attempt': 527,
#  'murder': 528,
#  'david': 529,
#  'shown': 530,
#  'english': 531,
#  'james': 532,
#  'happened': 533,
#  'taken': 534,
#  'husband': 535,
#  'gore': 536,
#  'save': 537,
#  'seriously': 538,
#  'jokes': 539,
#  'number': 540,
#  'across': 541,
#  'opening': 542,
#  'released': 543,
#  'none': 544,
#  'robert': 545,
#  'exactly': 546,
#  'career': 547,
#  'interest': 548,
#  'alone': 549,
#  'possible': 550,
#  'order': 551,
#  'talent': 552,
#  'running': 553,
#  'sad': 554,
#  'important': 555,
#  'annoying': 556,
#  'hours': 557,
#  'documentary': 558,
#  'saying': 559,
#  'd': 560,
#  'cinematography': 561,
#  'relationship': 562,
#  'wish': 563,
#  'usually': 564,
#  'shots': 565,
#  'whose': 566,
#  'taking': 567,
#  'huge': 568,
#  'room': 569,
#  'view': 570,
#  'started': 571,
#  'word': 572,
#  'light': 573,
#  'call': 574,
#  'mostly': 575,
#  'middle': 576,
#  'ones': 577,
#  'ridiculous': 578,
#  'other': 579,
#  'level': 580,
#  'power': 581,
#  'change': 582,
#  'words': 583,
#  'beyond': 584,
#  'four': 585,
#  'country': 586,
#  'silly': 587,
#  'scary': 588,
#  'ends': 589,
#  'opinion': 590,
#  'knows': 591,
#  'body': 592,
#  'turned': 593,
#  're': 594,
#  'novel': 595,
#  'happy': 596,
#  'usual': 597,
#  'single': 598,
#  'rating': 599,
#  'jack': 600,
#  'major': 601,
#  'apparently': 602,
#  'upon': 603,
#  'female': 604,
#  'knew': 605,
#  'non': 606,
#  'disappointed': 607,
#  'why': 608,
#  'talking': 609,
#  'modern': 610,
#  'somewhat': 611,
#  'attention': 612,
#  'television': 613,
#  'basically': 614,
#  'finds': 615,
#  'king': 616,
#  'cheap': 617,
#  'strange': 618,
#  'local': 619,
#  'due': 620,
#  'episodes': 621,
#  'team': 622,
#  'musical': 623,
#  'about': 624,
#  'earth': 625,
#  'miss': 626,
#  'thriller': 627,
#  'm': 628,
#  '7': 629,
#  'problems': 630,
#  'british': 631,
#  'class': 632,
#  'five': 633,
#  'events': 634,
#  'aren': 635,
#  'moving': 636,
#  'sequence': 637,
#  'talk': 638,
#  'down': 639,
#  'clearly': 640,
#  'comic': 641,
#  'before': 642,
#  'add': 643,
#  'predictable': 644,
#  'die': 645,
#  'lots': 646,
#  'o': 647,
#  'space': 648,
#  'french': 649,
#  'tells': 650,
#  'review': 651,
#  'songs': 652,
#  'he': 653,
#  'straight': 654,
#  'entertainment': 655,
#  'hate': 656,
#  '8': 657,
#  'whether': 658,
#  'ten': 659,
#  'enjoyable': 660,
#  'near': 661,
#  'romantic': 662,
#  'george': 663,
#  'rock': 664,
#  'fast': 665,
#  'giving': 666,
#  'bring': 667,
#  'clear': 668,
#  'appears': 669,
#  'easily': 670,
#  'haven': 671,
#  'sets': 672,
#  'sequel': 673,
#  'future': 674,
#  'soundtrack': 675,
#  'suspense': 676,
#  'message': 677,
#  'surprised': 678,
#  'mention': 679,
#  'falls': 680,
#  'dialog': 681,
#  'filmed': 682,
#  'eye': 683,
#  'similar': 684,
#  'within': 685,
#  'dull': 686,
#  'needs': 687,
#  'supporting': 688,
#  'parents': 689,
#  've': 690,
#  'monster': 691,
#  'release': 692,
#  'tried': 693,
#  'among': 694,
#  'ways': 695,
#  'certain': 696,
#  'easy': 697,
#  'nearly': 698,
#  'sorry': 699,
#  'working': 700,
#  'theater': 701,
#  'bunch': 702,
#  'sister': 703,
#  'did': 704,
#  'using': 705,
#  'showing': 706,
#  'theme': 707,
#  'storyline': 708,
#  'minute': 709,
#  '9': 710,
#  'at': 711,
#  'gone': 712,
#  'tale': 713,
#  'lady': 714,
#  'stay': 715,
#  'fall': 716,
#  'effort': 717,
#  'comments': 718,
#  'stand': 719,
#  'feature': 720,
#  'subject': 721,
#  'realistic': 722,
#  'viewers': 723,
#  'doubt': 724,
#  'typical': 725,
#  'editing': 726,
#  'mystery': 727,
#  'oscar': 728,
#  'feels': 729,
#  'elements': 730,
#  'named': 731,
#  'dr': 732,
#  'crime': 733,
#  'imagine': 734,
#  'famous': 735,
#  'general': 736,
#  'buy': 737,
#  'fantastic': 738,
#  'dog': 739,
#  'okay': 740,
#  'richard': 741,
#  'check': 742,
#  'kept': 743,
#  'paul': 744,
#  'points': 745,
#  'follow': 746,
#  'peter': 747,
#  'greatest': 748,
#  'red': 749,
#  'avoid': 750,
#  'means': 751,
#  'rent': 752,
#  'deal': 753,
#  'material': 754,
#  'viewing': 755,
#  'believable': 756,
#  'forget': 757,
#  'brought': 758,
#  'weak': 759,
#  'somehow': 760,
#  'reviews': 761,
#  'figure': 762,
#  'tom': 763,
#  'begins': 764,
#  'leads': 765,
#  'form': 766,
#  'expected': 767,
#  'period': 768,
#  'sit': 769,
#  'hear': 770,
#  'wait': 771,
#  'doctor': 772,
#  'average': 773,
#  'situation': 774,
#  'imdb': 775,
#  'move': 776,
#  'actual': 777,
#  'lame': 778,
#  'surprise': 779,
#  'open': 780,
#  '20': 781,
#  'sequences': 782,
#  'animation': 783,
#  'killing': 784,
#  'note': 785,
#  'whatever': 786,
#  'dance': 787,
#  'deep': 788,
#  'eventually': 789,
#  'fi': 790,
#  'york': 791,
#  'learn': 792,
#  'box': 793,
#  'sci': 794,
#  'decided': 795,
#  'america': 796,
#  'boys': 797,
#  'season': 798,
#  'indeed': 799,
#  'my': 800,
#  'atmosphere': 801,
#  'hot': 802,
#  'premise': 803,
#  'shame': 804,
#  'de': 805,
#  'memorable': 806,
#  'leaves': 807,
#  'poorly': 808,
#  'street': 809,
#  'difficult': 810,
#  'third': 811,
#  'are': 812,
#  'society': 813,
#  'free': 814,
#  'particular': 815,
#  'western': 816,
#  'truth': 817,
#  'crew': 818,
#  'e': 819,
#  'possibly': 820,
#  'credits': 821,
#  'romance': 822,
#  'needed': 823,
#  'begin': 824,
#  'otherwise': 825,
#  'write': 826,
#  'lee': 827,
#  'reading': 828,
#  'gay': 829,
#  'emotional': 830,
#  'acted': 831,
#  'became': 832,
#  'sexual': 833,
#  'question': 834,
#  'beauty': 835,
#  'perfectly': 836,
#  'forced': 837,
#  'meet': 838,
#  'masterpiece': 839,
#  'air': 840,
#  'male': 841,
#  'hands': 842,
#  'stage': 843,
#  'footage': 844,
#  'unless': 845,
#  'superb': 846,
#  'personal': 847,
#  'screenplay': 848,
#  'inside': 849,
#  'mark': 850,
#  'laughs': 851,
#  'effect': 852,
#  'forward': 853,
#  'meets': 854,
#  'writers': 855,
#  'island': 856,
#  'plus': 857,
#  'weird': 858,
#  'himself': 859,
#  'incredibly': 860,
#  'features': 861,
#  'comment': 862,
#  '80': 863,
#  'result': 864,
#  'battle': 865,
#  'disney': 866,
#  'setting': 867,
#  'nature': 868,
#  'girlfriend': 869,
#  'japanese': 870,
#  'baby': 871,
#  'cheesy': 872,
#  'badly': 873,
#  'total': 874,
#  'quickly': 875,
#  'unique': 876,
#  'fire': 877,
#  'towards': 878,
#  'interested': 879,
#  'cop': 880,
#  'crazy': 881,
#  'previous': 882,
#  'background': 883,
#  'sounds': 884,
#  'directors': 885,
#  'copy': 886,
#  'dumb': 887,
#  'various': 888,
#  'water': 889,
#  'earlier': 890,
#  'rate': 891,
#  'gun': 892,
#  'worked': 893,
#  'following': 894,
#  'powerful': 895,
#  'keeps': 896,
#  'joke': 897,
#  'dramatic': 898,
#  'older': 899,
#  'appear': 900,
#  'realize': 901,
#  'pay': 902,
#  'directing': 903,
#  'joe': 904,
#  'era': 905,
#  'cover': 906,
#  'mess': 907,
#  'business': 908,
#  'zombie': 909,
#  'creepy': 910,
#  '30': 911,
#  'ask': 912,
#  'front': 913,
#  'dream': 914,
#  'brings': 915,
#  'portrayed': 916,
#  'telling': 917,
#  'admit': 918,
#  'leading': 919,
#  'meant': 920,
#  'plenty': 921,
#  'they': 922,
#  'william': 923,
#  'wasted': 924,
#  'fairly': 925,
#  'match': 926,
#  'rich': 927,
#  'development': 928,
#  'political': 929,
#  'fails': 930,
#  'spent': 931,
#  'outside': 932,
#  'present': 933,
#  'reasons': 934,
#  'from': 935,
#  'apart': 936,
#  'agree': 937,
#  'german': 938,
#  'bill': 939,
#  'party': 940,
#  'manages': 941,
#  'success': 942,
#  'hardly': 943,
#  'when': 944,
#  'twist': 945,
#  'talented': 946,
#  'cartoon': 947,
#  'fighting': 948,
#  'while': 949,
#  'caught': 950,
#  'break': 951,
#  'attempts': 952,
#  'deserves': 953,
#  'recently': 954,
#  'c': 955,
#  'missing': 956,
#  'expecting': 957,
#  'ideas': 958,
#  'public': 959,
#  'ended': 960,
#  'fantasy': 961,
#  'villain': 962,
#  'we': 963,
#  'create': 964,
#  'secret': 965,
#  'remake': 966,
#  'clever': 967,
#  'itself': 968,
#  'office': 969,
#  'large': 970,
#  'married': 971,
#  'pure': 972,
#  'unlike': 973,
#  'italian': 974,
#  'missed': 975,
#  'potential': 976,
#  'produced': 977,
#  'return': 978,
#  'cute': 979,
#  'nudity': 980,
#  'laughing': 981,
#  'company': 982,
#  'century': 983,
#  'state': 984,
#  'escape': 985,
#  'members': 986,
#  'incredible': 987,
#  'pace': 988,
#  'waiting': 989,
#  'casting': 990,
#  'odd': 991,
#  'train': 992,
#  '6': 993,
#  'spoilers': 994,
#  'sadly': 995,
#  'created': 996,
#  'visual': 997,
#  'list': 998,
#  'considering': 999,
#  'filmmakers': 1000,
#  ...}

# %%
tokenizer = Tokenizer(num_words=5000)
tokenizer.fit_on_texts(X_train)

words_to_index = tokenizer.word_index

# %%
def read_glove_vector(glove_vec):
    with open(glove_vec, 'r', encoding='UTF-8') as f:
        words = set()
        word_to_vec_map = {}
        for line in f:
            w_line = line.split()
            curr_word = w_line[0]
            word_to_vec_map[curr_word] = np.array(w_line[1:], dtype=np.float64)
    return word_to_vec_map

# %%
word_to_vec_map = read_glove_vector('../../GCAE/glove.6B/glove.6B.300d.txt')

maxLen = 300

# %%
words_to_index
# Out:
# {'movie': 1,
#  'film': 2,
#  's': 3,
#  't': 4,
#  'not': 5,
#  'one': 6,
#  'like': 7,
#  'just': 8,
#  'good': 9,
#  'it': 10,
#  'can': 11,
#  'the': 12,
#  'no': 13,
#  'time': 14,
#  'even': 15,
#  'really': 16,
#  'story': 17,
#  'see': 18,
#  'well': 19,
#  'much': 20,
#  'bad': 21,
#  'get': 22,
#  'great': 23,
#  'people': 24,
#  'will': 25,
#  'also': 26,
#  'first': 27,
#  'don': 28,
#  'made': 29,
#  'make': 30,
#  'way': 31,
#  'i': 32,
#  'movies': 33,
#  'characters': 34,
#  'think': 35,
#  'character': 36,
#  'watch': 37,
#  'films': 38,
#  'two': 39,
#  'many': 40,
#  'seen': 41,
#  'love': 42,
#  'plot': 43,
#  'acting': 44,
#  'never': 45,
#  'life': 46,
#  'best': 47,
#  'show': 48,
#  'know': 49,
#  'this': 50,
#  'little': 51,
#  'ever': 52,
#  'off': 53,
#  'man': 54,
#  'better': 55,
#  'end': 56,
#  'still': 57,
#  'scene': 58,
#  'say': 59,
#  'and': 60,
#  'scenes': 61,
#  'something': 62,
#  'go': 63,
#  'back': 64,
#  'real': 65,
#  'now': 66,
#  'thing': 67,
#  'watching': 68,
#  'actors': 69,
#  'director': 70,
#  'years': 71,
#  'funny': 72,
#  'didn': 73,
#  'though': 74,
#  'doesn': 75,
#  'old': 76,
#  'another': 77,
#  'work': 78,
#  '10': 79,
#  'actually': 80,
#  'nothing': 81,
#  'makes': 82,
#  'look': 83,
#  'all': 84,
#  'find': 85,
#  'going': 86,
#  'new': 87,
#  'lot': 88,
#  'every': 89,
#  'part': 90,
#  'cast': 91,
#  'world': 92,
#  'that': 93,
#  'us': 94,
#  'things': 95,
#  'pretty': 96,
#  'horror': 97,
#  'quite': 98,
#  'want': 99,
#  'around': 100,
#  'seems': 101,
#  'however': 102,
#  'take': 103,
#  'young': 104,
#  'big': 105,
#  'fact': 106,
#  'got': 107,
#  'thought': 108,
#  'in': 109,
#  'long': 110,
#  'enough': 111,
#  'give': 112,
#  'may': 113,
#  'series': 114,
#  'comedy': 115,
#  'right': 116,
#  'must': 117,
#  'action': 118,
#  'music': 119,
#  'guy': 120,
#  'almost': 121,
#  'without': 122,
#  'always': 123,
#  'role': 124,
#  'times': 125,
#  'saw': 126,
#  'original': 127,
#  'come': 128,
#  'point': 129,
#  'isn': 130,
#  'gets': 131,
#  'interesting': 132,
#  'a': 133,
#  'is': 134,
#  'whole': 135,
#  'done': 136,
#  'least': 137,
#  'script': 138,
#  'far': 139,
#  'me': 140,
#  'bit': 141,
#  '2': 142,
#  'anything': 143,
#  'feel': 144,
#  'minutes': 145,
#  'might': 146,
#  'family': 147,
#  'there': 148,
#  'making': 149,
#  'tv': 150,
#  'since': 151,
#  'last': 152,
#  'probably': 153,
#  'but': 154,
#  'kind': 155,
#  'away': 156,
#  'performance': 157,
#  'yet': 158,
#  'girl': 159,
#  'fun': 160,
#  'worst': 161,
#  'anyone': 162,
#  'woman': 163,
#  'sure': 164,
#  'hard': 165,
#  'rather': 166,
#  'day': 167,
#  'out': 168,
#  'found': 169,
#  'played': 170,
#  'on': 171,
#  'you': 172,
#  'them': 173,
#  'screen': 174,
#  'although': 175,
#  'looking': 176,
#  'especially': 177,
#  'believe': 178,
#  'him': 179,
#  'up': 180,
#  'so': 181,
#  'dvd': 182,
#  'trying': 183,
#  'everything': 184,
#  'course': 185,
#  'here': 186,
#  'set': 187,
#  'comes': 188,
#  'put': 189,
#  'ending': 190,
#  'maybe': 191,
#  'goes': 192,
#  'shows': 193,
#  'different': 194,
#  'worth': 195,
#  'place': 196,
#  'actor': 197,
#  'three': 198,
#  'book': 199,
#  'sense': 200,
#  'looks': 201,
#  'effects': 202,
#  'year': 203,
#  'someone': 204,
#  'money': 205,
#  'main': 206,
#  'american': 207,
#  'play': 208,
#  'true': 209,
#  'everyone': 210,
#  'watched': 211,
#  'reason': 212,
#  'job': 213,
#  'war': 214,
#  'wasn': 215,
#  'together': 216,
#  'again': 217,
#  'high': 218,
#  'plays': 219,
#  'said': 220,
#  'instead': 221,
#  'audience': 222,
#  'half': 223,
#  'later': 224,
#  'special': 225,
#  '1': 226,
#  'takes': 227,
#  'night': 228,
#  'seeing': 229,
#  'beautiful': 230,
#  'john': 231,
#  'black': 232,
#  'seem': 233,
#  'excellent': 234,
#  'left': 235,
#  'idea': 236,
#  'shot': 237,
#  'wife': 238,
#  'version': 239,
#  'house': 240,
#  'else': 241,
#  'star': 242,
#  'mind': 243,
#  'fan': 244,
#  'father': 245,
#  'nice': 246,
#  'used': 247,
#  'death': 248,
#  'short': 249,
#  'simply': 250,
#  'completely': 251,
#  'poor': 252,
#  'budget': 253,
#  'men': 254,
#  '3': 255,
#  'read': 256,
#  'second': 257,
#  'top': 258,
#  'less': 259,
#  'along': 260,
#  'hollywood': 261,
#  'let': 262,
#  'home': 263,
#  'kids': 264,
#  'line': 265,
#  'help': 266,
#  'either': 267,
#  'friends': 268,
#  'wrong': 269,
#  'dead': 270,
#  'enjoy': 271,
#  'boring': 272,
#  'school': 273,
#  'women': 274,
#  'camera': 275,
#  'need': 276,
#  'classic': 277,
#  'given': 278,
#  'try': 279,
#  'to': 280,
#  'use': 281,
#  'stupid': 282,
#  'production': 283,
#  'full': 284,
#  'low': 285,
#  'rest': 286,
#  'performances': 287,
#  'her': 288,
#  'as': 289,
#  'truly': 290,
#  'next': 291,
#  'couple': 292,
#  'start': 293,
#  'awful': 294,
#  'video': 295,
#  'too': 296,
#  'came': 297,
#  'sex': 298,
#  'recommend': 299,
#  'tell': 300,
#  'terrible': 301,
#  'getting': 302,
#  'name': 303,
#  'remember': 304,
#  'understand': 305,
#  'won': 306,
#  'perhaps': 307,
#  'mean': 308,
#  'moments': 309,
#  'mother': 310,
#  'person': 311,
#  'episode': 312,
#  'style': 313,
#  'small': 314,
#  'if': 315,
#  'playing': 316,
#  'keep': 317,
#  'definitely': 318,
#  'perfect': 319,
#  'others': 320,
#  'human': 321,
#  'wonderful': 322,
#  'face': 323,
#  'often': 324,
#  'early': 325,
#  'written': 326,
#  'head': 327,
#  'boy': 328,
#  'lines': 329,
#  'stars': 330,
#  'dialogue': 331,
#  'children': 332,
#  'couldn': 333,
#  'piece': 334,
#  'yes': 335,
#  'title': 336,
#  'finally': 337,
#  'laugh': 338,
#  'gives': 339,
#  'went': 340,
#  'case': 341,
#  'certainly': 342,
#  'absolutely': 343,
#  'live': 344,
#  'sort': 345,
#  'lost': 346,
#  'oh': 347,
#  'friend': 348,
#  'loved': 349,
#  'cinema': 350,
#  'entertaining': 351,
#  'worse': 352,
#  'become': 353,
#  'called': 354,
#  'hope': 355,
#  'picture': 356,
#  'for': 357,
#  'guys': 358,
#  'mr': 359,
#  'overall': 360,
#  'several': 361,
#  'felt': 362,
#  'liked': 363,
#  'drama': 364,
#  'what': 365,
#  'supposed': 366,
#  'based': 367,
#  'entire': 368,
#  'white': 369,
#  'problem': 370,
#  'beginning': 371,
#  'with': 372,
#  '4': 373,
#  'fans': 374,
#  'waste': 375,
#  'humor': 376,
#  'totally': 377,
#  'care': 378,
#  'evil': 379,
#  'sound': 380,
#  'dark': 381,
#  'despite': 382,
#  'final': 383,
#  'seemed': 384,
#  '5': 385,
#  'direction': 386,
#  'wanted': 387,
#  'example': 388,
#  'game': 389,
#  'already': 390,
#  'son': 391,
#  'lead': 392,
#  'who': 393,
#  'lives': 394,
#  'of': 395,
#  'becomes': 396,
#  'guess': 397,
#  'throughout': 398,
#  'michael': 399,
#  'turn': 400,
#  'killer': 401,
#  'quality': 402,
#  'unfortunately': 403,
#  'able': 404,
#  'side': 405,
#  'history': 406,
#  'over': 407,
#  'b': 408,
#  'fine': 409,
#  'days': 410,
#  'run': 411,
#  'writing': 412,
#  'viewer': 413,
#  'horrible': 414,
#  'god': 415,
#  'flick': 416,
#  'be': 417,
#  'child': 418,
#  'today': 419,
#  'wants': 420,
#  'heart': 421,
#  'close': 422,
#  'act': 423,
#  'town': 424,
#  '\x96': 425,
#  'or': 426,
#  'do': 427,
#  'kill': 428,
#  'past': 429,
#  'stuff': 430,
#  'amazing': 431,
#  'matter': 432,
#  'art': 433,
#  'works': 434,
#  'car': 435,
#  'kid': 436,
#  'favorite': 437,
#  'gave': 438,
#  'genre': 439,
#  'enjoyed': 440,
#  'etc': 441,
#  'hand': 442,
#  'eyes': 443,
#  'tries': 444,
#  'expect': 445,
#  'hour': 446,
#  'girls': 447,
#  'brilliant': 448,
#  'turns': 449,
#  'late': 450,
#  'soon': 451,
#  'behind': 452,
#  'parts': 453,
#  'sometimes': 454,
#  'directed': 455,
#  'killed': 456,
#  'highly': 457,
#  'actress': 458,
#  'obviously': 459,
#  'daughter': 460,
#  'thinking': 461,
#  'was': 462,
#  'says': 463,
#  'city': 464,
#  'type': 465,
#  'voice': 466,
#  'which': 467,
#  'then': 468,
#  'self': 469,
#  'group': 470,
#  'feeling': 471,
#  'decent': 472,
#  'starts': 473,
#  'experience': 474,
#  'writer': 475,
#  'heard': 476,
#  'took': 477,
#  'stop': 478,
#  'anyway': 479,
#  'known': 480,
#  'blood': 481,
#  'except': 482,
#  'slow': 483,
#  'happens': 484,
#  'moment': 485,
#  'fight': 486,
#  'coming': 487,
#  'involved': 488,
#  'police': 489,
#  'leave': 490,
#  'chance': 491,
#  'lack': 492,
#  'hell': 493,
#  'score': 494,
#  'cannot': 495,
#  'strong': 496,
#  'stories': 497,
#  'told': 498,
#  'crap': 499,
#  'extremely': 500,
#  'roles': 501,
#  'please': 502,
#  'wouldn': 503,
#  'wonder': 504,
#  'hilarious': 505,
#  'more': 506,
#  'hit': 507,
#  'including': 508,
#  'violence': 509,
#  'song': 510,
#  'happen': 511,
#  'hero': 512,
#  'obvious': 513,
#  'particularly': 514,
#  'cool': 515,
#  'living': 516,
#  'serious': 517,
#  'brother': 518,
#  'cut': 519,
#  'simple': 520,
#  'ok': 521,
#  'looked': 522,
#  'age': 523,
#  'complete': 524,
#  'ago': 525,
#  'reality': 526,
#  'attempt': 527,
#  'murder': 528,
#  'david': 529,
#  'shown': 530,
#  'english': 531,
#  'james': 532,
#  'happened': 533,
#  'taken': 534,
#  'husband': 535,
#  'gore': 536,
#  'save': 537,
#  'seriously': 538,
#  'jokes': 539,
#  'number': 540,
#  'across': 541,
#  'opening': 542,
#  'released': 543,
#  'none': 544,
#  'robert': 545,
#  'exactly': 546,
#  'career': 547,
#  'interest': 548,
#  'alone': 549,
#  'possible': 550,
#  'order': 551,
#  'talent': 552,
#  'running': 553,
#  'sad': 554,
#  'important': 555,
#  'annoying': 556,
#  'hours': 557,
#  'documentary': 558,
#  'saying': 559,
#  'd': 560,
#  'cinematography': 561,
#  'relationship': 562,
#  'wish': 563,
#  'usually': 564,
#  'shots': 565,
#  'whose': 566,
#  'taking': 567,
#  'huge': 568,
#  'room': 569,
#  'view': 570,
#  'started': 571,
#  'word': 572,
#  'light': 573,
#  'call': 574,
#  'mostly': 575,
#  'middle': 576,
#  'ones': 577,
#  'ridiculous': 578,
#  'other': 579,
#  'level': 580,
#  'power': 581,
#  'change': 582,
#  'words': 583,
#  'beyond': 584,
#  'four': 585,
#  'country': 586,
#  'silly': 587,
#  'scary': 588,
#  'ends': 589,
#  'opinion': 590,
#  'knows': 591,
#  'body': 592,
#  'turned': 593,
#  're': 594,
#  'novel': 595,
#  'happy': 596,
#  'usual': 597,
#  'single': 598,
#  'rating': 599,
#  'jack': 600,
#  'major': 601,
#  'apparently': 602,
#  'upon': 603,
#  'female': 604,
#  'knew': 605,
#  'non': 606,
#  'disappointed': 607,
#  'why': 608,
#  'talking': 609,
#  'modern': 610,
#  'somewhat': 611,
#  'attention': 612,
#  'television': 613,
#  'basically': 614,
#  'finds': 615,
#  'king': 616,
#  'cheap': 617,
#  'strange': 618,
#  'local': 619,
#  'due': 620,
#  'episodes': 621,
#  'team': 622,
#  'musical': 623,
#  'about': 624,
#  'earth': 625,
#  'miss': 626,
#  'thriller': 627,
#  'm': 628,
#  '7': 629,
#  'problems': 630,
#  'british': 631,
#  'class': 632,
#  'five': 633,
#  'events': 634,
#  'aren': 635,
#  'moving': 636,
#  'sequence': 637,
#  'talk': 638,
#  'down': 639,
#  'clearly': 640,
#  'comic': 641,
#  'before': 642,
#  'add': 643,
#  'predictable': 644,
#  'die': 645,
#  'lots': 646,
#  'o': 647,
#  'space': 648,
#  'french': 649,
#  'tells': 650,
#  'review': 651,
#  'songs': 652,
#  'he': 653,
#  'straight': 654,
#  'entertainment': 655,
#  'hate': 656,
#  '8': 657,
#  'whether': 658,
#  'ten': 659,
#  'enjoyable': 660,
#  'near': 661,
#  'romantic': 662,
#  'george': 663,
#  'rock': 664,
#  'fast': 665,
#  'giving': 666,
#  'bring': 667,
#  'clear': 668,
#  'appears': 669,
#  'easily': 670,
#  'haven': 671,
#  'sets': 672,
#  'sequel': 673,
#  'future': 674,
#  'soundtrack': 675,
#  'suspense': 676,
#  'message': 677,
#  'surprised': 678,
#  'mention': 679,
#  'falls': 680,
#  'dialog': 681,
#  'filmed': 682,
#  'eye': 683,
#  'similar': 684,
#  'within': 685,
#  'dull': 686,
#  'needs': 687,
#  'supporting': 688,
#  'parents': 689,
#  've': 690,
#  'monster': 691,
#  'release': 692,
#  'tried': 693,
#  'among': 694,
#  'ways': 695,
#  'certain': 696,
#  'easy': 697,
#  'nearly': 698,
#  'sorry': 699,
#  'working': 700,
#  'theater': 701,
#  'bunch': 702,
#  'sister': 703,
#  'did': 704,
#  'using': 705,
#  'showing': 706,
#  'theme': 707,
#  'storyline': 708,
#  'minute': 709,
#  '9': 710,
#  'at': 711,
#  'gone': 712,
#  'tale': 713,
#  'lady': 714,
#  'stay': 715,
#  'fall': 716,
#  'effort': 717,
#  'comments': 718,
#  'stand': 719,
#  'feature': 720,
#  'subject': 721,
#  'realistic': 722,
#  'viewers': 723,
#  'doubt': 724,
#  'typical': 725,
#  'editing': 726,
#  'mystery': 727,
#  'oscar': 728,
#  'feels': 729,
#  'elements': 730,
#  'named': 731,
#  'dr': 732,
#  'crime': 733,
#  'imagine': 734,
#  'famous': 735,
#  'general': 736,
#  'buy': 737,
#  'fantastic': 738,
#  'dog': 739,
#  'okay': 740,
#  'richard': 741,
#  'check': 742,
#  'kept': 743,
#  'paul': 744,
#  'points': 745,
#  'follow': 746,
#  'peter': 747,
#  'greatest': 748,
#  'red': 749,
#  'avoid': 750,
#  'means': 751,
#  'rent': 752,
#  'deal': 753,
#  'material': 754,
#  'viewing': 755,
#  'believable': 756,
#  'forget': 757,
#  'brought': 758,
#  'weak': 759,
#  'somehow': 760,
#  'reviews': 761,
#  'figure': 762,
#  'tom': 763,
#  'begins': 764,
#  'leads': 765,
#  'form': 766,
#  'expected': 767,
#  'period': 768,
#  'sit': 769,
#  'hear': 770,
#  'wait': 771,
#  'doctor': 772,
#  'average': 773,
#  'situation': 774,
#  'imdb': 775,
#  'move': 776,
#  'actual': 777,
#  'lame': 778,
#  'surprise': 779,
#  'open': 780,
#  '20': 781,
#  'sequences': 782,
#  'animation': 783,
#  'killing': 784,
#  'note': 785,
#  'whatever': 786,
#  'dance': 787,
#  'deep': 788,
#  'eventually': 789,
#  'fi': 790,
#  'york': 791,
#  'learn': 792,
#  'box': 793,
#  'sci': 794,
#  'decided': 795,
#  'america': 796,
#  'boys': 797,
#  'season': 798,
#  'indeed': 799,
#  'my': 800,
#  'atmosphere': 801,
#  'hot': 802,
#  'premise': 803,
#  'shame': 804,
#  'de': 805,
#  'memorable': 806,
#  'leaves': 807,
#  'poorly': 808,
#  'street': 809,
#  'difficult': 810,
#  'third': 811,
#  'are': 812,
#  'society': 813,
#  'free': 814,
#  'particular': 815,
#  'western': 816,
#  'truth': 817,
#  'crew': 818,
#  'e': 819,
#  'possibly': 820,
#  'credits': 821,
#  'romance': 822,
#  'needed': 823,
#  'begin': 824,
#  'otherwise': 825,
#  'write': 826,
#  'lee': 827,
#  'reading': 828,
#  'gay': 829,
#  'emotional': 830,
#  'acted': 831,
#  'became': 832,
#  'sexual': 833,
#  'question': 834,
#  'beauty': 835,
#  'perfectly': 836,
#  'forced': 837,
#  'meet': 838,
#  'masterpiece': 839,
#  'air': 840,
#  'male': 841,
#  'hands': 842,
#  'stage': 843,
#  'footage': 844,
#  'unless': 845,
#  'superb': 846,
#  'personal': 847,
#  'screenplay': 848,
#  'inside': 849,
#  'mark': 850,
#  'laughs': 851,
#  'effect': 852,
#  'forward': 853,
#  'meets': 854,
#  'writers': 855,
#  'island': 856,
#  'plus': 857,
#  'weird': 858,
#  'himself': 859,
#  'incredibly': 860,
#  'features': 861,
#  'comment': 862,
#  '80': 863,
#  'result': 864,
#  'battle': 865,
#  'disney': 866,
#  'setting': 867,
#  'nature': 868,
#  'girlfriend': 869,
#  'japanese': 870,
#  'baby': 871,
#  'cheesy': 872,
#  'badly': 873,
#  'total': 874,
#  'quickly': 875,
#  'unique': 876,
#  'fire': 877,
#  'towards': 878,
#  'interested': 879,
#  'cop': 880,
#  'crazy': 881,
#  'previous': 882,
#  'background': 883,
#  'sounds': 884,
#  'directors': 885,
#  'copy': 886,
#  'dumb': 887,
#  'various': 888,
#  'water': 889,
#  'earlier': 890,
#  'rate': 891,
#  'gun': 892,
#  'worked': 893,
#  'following': 894,
#  'powerful': 895,
#  'keeps': 896,
#  'joke': 897,
#  'dramatic': 898,
#  'older': 899,
#  'appear': 900,
#  'realize': 901,
#  'pay': 902,
#  'directing': 903,
#  'joe': 904,
#  'era': 905,
#  'cover': 906,
#  'mess': 907,
#  'business': 908,
#  'zombie': 909,
#  'creepy': 910,
#  '30': 911,
#  'ask': 912,
#  'front': 913,
#  'dream': 914,
#  'brings': 915,
#  'portrayed': 916,
#  'telling': 917,
#  'admit': 918,
#  'leading': 919,
#  'meant': 920,
#  'plenty': 921,
#  'they': 922,
#  'william': 923,
#  'wasted': 924,
#  'fairly': 925,
#  'match': 926,
#  'rich': 927,
#  'development': 928,
#  'political': 929,
#  'fails': 930,
#  'spent': 931,
#  'outside': 932,
#  'present': 933,
#  'reasons': 934,
#  'from': 935,
#  'apart': 936,
#  'agree': 937,
#  'german': 938,
#  'bill': 939,
#  'party': 940,
#  'manages': 941,
#  'success': 942,
#  'hardly': 943,
#  'when': 944,
#  'twist': 945,
#  'talented': 946,
#  'cartoon': 947,
#  'fighting': 948,
#  'while': 949,
#  'caught': 950,
#  'break': 951,
#  'attempts': 952,
#  'deserves': 953,
#  'recently': 954,
#  'c': 955,
#  'missing': 956,
#  'expecting': 957,
#  'ideas': 958,
#  'public': 959,
#  'ended': 960,
#  'fantasy': 961,
#  'villain': 962,
#  'we': 963,
#  'create': 964,
#  'secret': 965,
#  'remake': 966,
#  'clever': 967,
#  'itself': 968,
#  'office': 969,
#  'large': 970,
#  'married': 971,
#  'pure': 972,
#  'unlike': 973,
#  'italian': 974,
#  'missed': 975,
#  'potential': 976,
#  'produced': 977,
#  'return': 978,
#  'cute': 979,
#  'nudity': 980,
#  'laughing': 981,
#  'company': 982,
#  'century': 983,
#  'state': 984,
#  'escape': 985,
#  'members': 986,
#  'incredible': 987,
#  'pace': 988,
#  'waiting': 989,
#  'casting': 990,
#  'odd': 991,
#  'train': 992,
#  '6': 993,
#  'spoilers': 994,
#  'sadly': 995,
#  'created': 996,
#  'visual': 997,
#  'list': 998,
#  'considering': 999,
#  'filmmakers': 1000,
#  ...}

# %%
vocab_len = len(words_to_index)
embed_vector_len = maxLen

emb_matrix = np.zeros((vocab_len, embed_vector_len))

for word, index in words_to_index.items():
    embedding_vector = word_to_vec_map.get(word)
#     print(word," ", index, " ", embedding_vector)
    if embedding_vector is not None:
        emb_matrix[index, :] = embedding_vector
#     if embedding_vector is None:
#         print("hi")

embedding_layer = Embedding(input_dim=vocab_len, output_dim=embed_vector_len, input_length=maxLen, weights = [emb_matrix], trainable=False)

# %%
embedding_layer

# %%
def imdb_rating(input_shape):
    X_indices = Input(input_shape)
    embeddings = embedding_layer(X_indices)
    X = LSTM(128, return_sequences=True)(embeddings)
    X = Dropout(0.6)(X)
    X = LSTM(128, return_sequences=True)(X)
    X = Dropout(0.6)(X)
    X = LSTM(128)(X)
    X = Dense(1, activation='sigmoid')(X)
    model = Model(inputs=X_indices, outputs=X)
    print(model.summary())
    return model

# %%
model_lstm = imdb_rating(300)
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 300)]             0
# _________________________________________________________________
# embedding_2 (Embedding)      (None, 300, 300)          28625700
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 300, 128)          219648
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 300, 128)          0
# _________________________________________________________________
# lstm_8 (LSTM)                (None, 300, 128)          131584
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 300, 128)          0
# _________________________________________________________________
# lstm_9 (LSTM)                (None, 128)               131584
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 29,108,645
# Trainable params: 482,945
# Non-trainable params: 28,625,700
# _________________________________________________________________
# None

# %%
X_train_indices = tokenizer.texts_to_sequences(X_train)

X_train_indices = pad_sequences(X_train_indices, maxlen=maxLen, padding='post')

# %%
def test_cnn(emb):
    model = Sequential()
    model.add(emb)
    model.add(Conv1D(filters=32, kernel_size=8, activation='relu'))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Flatten())
    model.add(Dense(10, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    print(model.summary())
    return model

model = test_cnn(embedding_layer)
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 300, 300)          28625700
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 293, 32)           76832
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 146, 32)           0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 4672)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                46730
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 28,749,273
# Trainable params: 123,573
# Non-trainable params: 28,625,700
# _________________________________________________________________
# None

# %%
adam = keras.optimizers.Adam(learning_rate = 0.0001)

model.compile(optimizer=adam, loss='binary_crossentropy', metrics=['accuracy'])

model.fit(X_train_indices, Y_train, batch_size=64, epochs=5)
# Out:
# Epoch 1/5
# 625/625 [==============================] - 53s 85ms/step - loss: 0.5238 - accuracy: 0.7280
# Epoch 2/5
# 625/625 [==============================] - 54s 87ms/step - loss: 0.3832 - accuracy: 0.8308
# Epoch 3/5
# 625/625 [==============================] - 56s 90ms/step - loss: 0.3439 - accuracy: 0.8513
# Epoch 4/5
# 625/625 [==============================] - 59s 94ms/step - loss: 0.3152 - accuracy: 0.8665
# Epoch 5/5
# 625/625 [==============================] - 61s 97ms/step - loss: 0.2890 - accuracy: 0.8800

# %%
X_test_indices = tokenizer.texts_to_sequences(X_test)

X_test_indices = pad_sequences(X_test_indices, maxlen=maxLen, padding='post')

# %%
model.evaluate(X_test_indices, Y_test)
# Out:
# 313/313 [==============================] - 4s 14ms/step - loss: 0.3548 - accuracy: 0.8459
# [0.35479459166526794, 0.8458999991416931]

# %%
preds = model.predict(X_test_indices)

n = np.random.randint(0,9999)

preds
# Out:
# array([[0.01790246],
#        [0.32854253],
#        [0.9774425 ],
#        ...,
#        [0.14328033],
#        [0.753605  ],
#        [0.01298296]], dtype=float32)

# %%
def add_score_predictions(reviews_list_idx):

    data['sentiment score'] = 0

    reviews_list_idx = pad_sequences(reviews_list_idx, maxlen=maxLen, padding='post')

    review_preds = model.predict(reviews_list_idx)

    data['sentiment score'] = review_preds

    pred_sentiment = np.array(list(map(lambda x : 'positive' if x > 0.5 else 'negative',review_preds)))

    data['predicted sentiment'] = 0

    data['predicted sentiment'] = pred_sentiment

    return data

# %%
pred_y = []
for i in preds:
    if i>0.5:
        pred_y.append(1)
    else:
        pred_y.append(0)

# %%
len(Y_test)
# Out:
# 10000

# %%
count = 0
for i in range(len(pred_y)):
    if(pred_y[i] == Y_test[i]):
        count += 1
count/10000
# Out:
# 0.8459
